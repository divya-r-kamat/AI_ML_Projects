# %% [markdown]
# ### Practice Questions - Bayes's theorem from Khan Academy

# %% [markdown]
# #### Question 1 :
# Denis examined the records of the clients who had joined his gym more than six months ago, and he found these statistics:
# \begin{aligned} &P(\text{joined in January})=0.12 \\\\ &P(\text{member for over 6 months})=0.5 \\\\ &P(\text{over 6 months and January})=0.024 \end{aligned}
#
# Find the probability that a client remained a member for more than 6 months, given that the client joined in January.
#
#
# P(over 6 months ∣ January)

# %%
0.024/0.12
# Out:
# 0.2

# %% [markdown]
# #### Question 2 :

# %% [markdown]
# ![KhanAQ2.PNG](attachment:KhanAQ2.PNG)

# %% [markdown]
# #### Question 3 :
#
# ![KhanAQ3.PNG](attachment:KhanAQ3.PNG)
#
#
# 40/(40+10)

# %% [markdown]
# #### Question 4:
#
# Vera examined a random sample of deodorants distributed by her company. She found the following probabilities:
# \begin{aligned} &P(\text{for men})=0.55 \\\\ &P(\text{botanic scent})=0.18 \\\\ &P(\text{for men and botanic})=0.05 \end{aligned}
#
# Find the probability that a deodorant is for men, given that it has a botanic scent.
#
# P(for men ∣ botanic)

# %%
0.05/0.18
# Out:
# 0.2777777777777778

# %% [markdown]
# #### Question 5:
#
# ![KhanAQ4.PNG](attachment:KhanAQ4.PNG)

# %% [markdown]
# #### Question 6:
#
# ![KhanAQ4.PNG](attachment:KhanAQ4.PNG)

# %% [markdown]
# #### Question 7:
#
# ![KhanAQ4.PNG](attachment:KhanAQ4.PNG)

# %% [markdown]
# #### Question8:
#
# ![KhanAQ4.PNG](attachment:KhanAQ4.PNG)

# %% [markdown]
# #### Question 9:
#
# ![KhanAQ4.PNG](attachment:KhanAQ4.PNG)

# %% [markdown]
# #### Question10:
#
# ![KhanAQ4.PNG](attachment:KhanAQ4.PNG)

# %% [markdown]
# #### Question 11:
#
# ![KhanAQ4.PNG](attachment:KhanAQ4.PNG)

# %% [markdown]
# a. What is the probability that a randomly selected graduate earns $40,000 and over?
# P(\$40{,}000 \text{ and over})=P($40,000 and over)

# %%
75/300
# Out:
# 0.25

# %% [markdown]
# b. What is the probability that a randomly selected graduate earns $40,000 and over given they are from University B?
# P(\$40{,}000 \text{ and over } | \text{ Uni. B})=P($40,000 and over ∣ Uni. B)

# %%
40/120
# Out:
# 0.3333333333333333

# %% [markdown]
# c. Are the events "income is $40,000 and over" and "attended University B" independent?
#
# #### No -
# ![KhanAQ4.PNG](attachment:KhanAQ4.PNG)

# %% [markdown]
# d. Are the events "income is under $20,000" and "attended University B" independent?
#
# #### YES
#
# ![KhanAQ4.PNG](attachment:KhanAQ4.PNG)
